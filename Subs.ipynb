# %% [markdown]
# <a href="https://colab.research.google.com/github/average81/KION/blob/scene_segmentation/Subs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# субтитры группируются в "сцены" по двум критериям: паузе во времени между субтитрами и семантической (смысловой) схожести текста с помощью spaCy

# %% [markdown]
#     Загружается модель spaCy для русского языка (ru_core_news_md), чтобы анализировать смысл текста субтитров.
#
#     Считывается и парсится файл субтитров SRT.
#
#     Каждая реплика субтитров превращается в объект с таймкодами, текстом и лингвистическим представлением.
#
#     Реплики группируются в сцены на основе временных разрывов между репликами и семантической схожести текста.
#
#     Проводится дополнительное объединение сцен, чтобы избежать слишком коротких сцен или искусственного дробления.
#
#     Итоговые сцены выводятся на экран и сохраняются в текстовый файл.

# %%
pip install pysrt
# Out:
# Collecting pysrt
#   Downloading pysrt-1.1.2.tar.gz (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.4/104.4 kB 694.3 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: chardet in /usr/local/lib/python3.11/dist-packages (from pysrt) (5.2.0)
# Building wheels for collected packages: pysrt
#   Building wheel for pysrt (setup.py) ... done
#   Created wheel for pysrt: filename=pysrt-1.1.2-py3-none-any.whl size=13443 sha256=aac3d3d13eea2a8a9bb3dd14342cf9e7be970246c71c6255e5ed86c5876f109d
#   Stored in directory: /root/.cache/pip/wheels/2d/b2/df/ea10959920533975b4a74a25a35e6d79655b63f3006611a99f
# Successfully built pysrt
# Installing collected packages: pysrt
# Successfully installed pysrt-1.1.2

# %%
# !python -m spacy download ru_core_news_md
# Out:
# Collecting ru-core-news-md==3.8.0
#   Using cached https://github.com/explosion/spacy-models/releases/download/ru_core_news_md-3.8.0/ru_core_news_md-3.8.0-py3-none-any.whl (41.9 MB)
# Requirement already satisfied: pymorphy3>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ru-core-news-md==3.8.0) (2.0.4)
# Requirement already satisfied: dawg2-python>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from pymorphy3>=1.0.0->ru-core-news-md==3.8.0) (0.9.0)
# Requirement already satisfied: pymorphy3-dicts-ru in /usr/local/lib/python3.11/dist-packages (from pymorphy3>=1.0.0->ru-core-news-md==3.8.0) (2.4.417150.4580142)
# ✔ Download and installation successful
# You can now load the package via spacy.load('ru_core_news_md')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
from dataclasses import dataclass
from typing import List, Tuple
import re
from statistics import mean

# Настройки
MIN_SCENE_DURATION = 10.0  # Минимальная длительность сцены в секундах
TIME_GAP_THRESHOLD = 3.0  # Максимальный допустимый разрыв между репликами
SIMILARITY_THRESHOLD = 0.55  # Порог семантической схожести
MAX_SCENE_DURATION = 240.0  # Максимальная длительность одной сцены

# Загружаем модель для русского языка
try:
    nlp = spacy.load("ru_core_news_md")
except OSError:
    print("Модель ru_core_news_md не найдена. Установите её командой:")
    print("python -m spacy download ru_core_news_md")
    exit()

@dataclass
class SubtitleLine:
    index: int
    start: float  # в секундах
    end: float    # в секундах
    text: str
    doc: any = None  # spaCy Doc объект

def read_srt_file(file_path: str) -> str:
    """Читает содержимое файла SRT"""
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            return file.read()
    except FileNotFoundError:
        print(f"Файл {file_path} не найден!")
        exit()
    except UnicodeDecodeError:
        try:
            with open(file_path, 'r', encoding='cp1251') as file:
                return file.read()
        except Exception as e:
            print(f"Ошибка при чтении файла: {e}")
            exit()

def parse_srt(srt_text: str) -> List[SubtitleLine]:
    subtitles = []
    blocks = re.split(r'\n\s*\n', srt_text.strip())

    for block in blocks:
        lines = block.strip().split('\n')
        if len(lines) < 3:
            continue

        try:
            index = int(lines[0])
            time_match = re.match(r'(\d{2}):(\d{2}):(\d{2}),(\d{3}) --> (\d{2}):(\d{2}):(\d{2}),(\d{3})', lines[1])
            if not time_match:
                continue

            h1, m1, s1, ms1 = map(int, time_match.groups()[:4])
            h2, m2, s2, ms2 = map(int, time_match.groups()[4:8])
            start = h1 * 3600 + m1 * 60 + s1 + ms1 / 1000
            end = h2 * 3600 + m2 * 60 + s2 + ms2 / 1000

            text = '\n'.join(lines[2:])
            doc = nlp(text)  # Анализируем текст с помощью spaCy
            subtitles.append(SubtitleLine(index, start, end, text, doc))
        except Exception as e:
            print(f"Ошибка при обработке блока: {e}")
            continue

    return subtitles

def calculate_scene_metrics(scene: List[SubtitleLine]) -> Tuple[float, float]:
    """Вычисляет длительность сцены и среднюю схожесть реплик"""
    if not scene:
        return 0.0, 0.0

    durations = [sub.end - sub.start for sub in scene]
    similarities = []

    for i in range(1, len(scene)):
        sim = scene[i-1].doc.similarity(scene[i].doc)
        similarities.append(sim)

    total_duration = scene[-1].end - scene[0].start
    avg_similarity = mean(similarities) if similarities else 1.0

    return total_duration, avg_similarity

def should_merge_scenes(prev_scene: List[SubtitleLine], current_scene: List[SubtitleLine]) -> bool:
    """Определяет, нужно ли объединять сцены"""
    if not prev_scene or not current_scene:
        return False

    # Проверяем временной промежуток между сценами
    time_gap = current_scene[0].start - prev_scene[-1].end

    # Проверяем схожесть последней реплики предыдущей сцены и первой текущей
    similarity = prev_scene[-1].doc.similarity(current_scene[0].doc)

    # Вычисляем общую длительность объединенной сцены
    merged_duration = current_scene[-1].end - prev_scene[0].start

    # Объединяем, если:
    # 1. Небольшой временной разрыв И хорошая схожесть
    # 2. ИЛИ если одна из сцен слишком короткая
    # 3. И при этом объединенная сцена не станет слишком длинной
    return ((time_gap <= TIME_GAP_THRESHOLD and similarity >= SIMILARITY_THRESHOLD) or
            any(calculate_scene_metrics(s)[0] < MIN_SCENE_DURATION for s in [prev_scene, current_scene])) and \
           merged_duration <= MAX_SCENE_DURATION

def group_into_scenes(subtitles: List[SubtitleLine]) -> List[List[SubtitleLine]]:
    if not subtitles:
        return []

    # Сначала группируем по простым правилам
    initial_scenes = []
    current_scene = [subtitles[0]]

    for prev_sub, curr_sub in zip(subtitles, subtitles[1:]):
        time_gap = curr_sub.start - prev_sub.end
        similarity = prev_sub.doc.similarity(curr_sub.doc) if prev_sub.doc and curr_sub.doc else 0

        if time_gap > TIME_GAP_THRESHOLD or similarity < SIMILARITY_THRESHOLD:
            initial_scenes.append(current_scene)
            current_scene = [curr_sub]
        else:
            current_scene.append(curr_sub)

    initial_scenes.append(current_scene)

    # Затем объединяем короткие или связанные сцены
    merged_scenes = []

    for scene in initial_scenes:
        if not merged_scenes:
            merged_scenes.append(scene)
            continue

        if should_merge_scenes(merged_scenes[-1], scene):
            merged_scenes[-1].extend(scene)
        else:
            merged_scenes.append(scene)

    return merged_scenes

def print_scenes(scenes: List[List[SubtitleLine]]):
    for i, scene in enumerate(scenes, 1):
        duration = scene[-1].end - scene[0].start
        num_dialogs = len(scene)
        print(f"\n=== Сцена {i} ({duration:.1f} сек, {num_dialogs} реплик) ===")
        for sub in scene:
            print(f"{sub.start:.1f}-{sub.end:.1f}: {sub.text}")

# Основной код
if __name__ == "__main__":
    # Укажите путь к вашему файлу субтитров
    srt_file_path = "Mr_And_Mrs_Smith_RUS_2005.srt"

    # Читаем файл
    srt_text = read_srt_file(srt_file_path)

    # Парсим и анализируем
    subtitles = parse_srt(srt_text)
    print(f"Обработано {len(subtitles)} реплик")

    scenes = group_into_scenes(subtitles)
    print(f"Выделено {len(scenes)} сцен")

    # Выводим результат
    print_scenes(scenes)

    # Сохраняем результат в файл
    with open("scenes_output.txt", "w", encoding="utf-8") as f:
        for i, scene in enumerate(scenes, 1):
            duration = scene[-1].end - scene[0].start
            f.write(f"\n=== Сцена {i} ({duration:.1f} сек) ===\n")
            for sub in scene:
                f.write(f"{sub.start:.2f}-{sub.end:.2f}: {sub.text}\n")
    print("\nРезультат также сохранён в файл scenes_output.txt")
# Out:
# Обработано 1079 реплик
# Выделено 53 сцен
#
# === Сцена 1 (184.2 сек, 47 реплик) ===
# 26.6-29.2: - Давайте, я первый.
# - Да.
# 29.4-31.7: Я думаю, что зря мы сюда пришли.
# 33.8-35.8: - Мы женаты уже пять лет.
# - Шесть.
# 36.3-38.0: Пять или шесть лет.
# 38.8-41.7: И для нас это,
# как ТО для машины.
# 41.9-44.8: Диагностика, проверка движка,
# 45.1-48.6: поменять масло,
# пару сальников.
# 51.9-54.4: Что ж, давайте откроем капот.
# 55.8-58.3: На сколько вы счастливы,
# как семья по десятибалльной шкале?
# 58.5-60.4: - Восемь.
# - Стойте.
# 60.6-64.8: Десятка - неописуемый восторг,
# а единица - полное непонимание?
# 65.0-67.0: Постарайтесь ответить интуитивно.
# 67.2-68.9: Хорошо.
# 69.1-70.1: - Ты готова?
# - Да.
# 70.4-71.6: - Восемь.
# - Восемь.
# 74.8-77.1: Вы часто занимаетесь сексом?
# 77.3-79.5: Я не понимаю вопроса.
# 80.0-82.9: Да, непонятно.
# По десятибалльной шкале?
# 83.1-87.0: Единица в этом случае -
# очень-очень мало или совсем нет?
# 87.2-91.6: Ведь тогда вашу шкалу
# нужно с нуля начинать.
# 95.1-97.8: Ну, хотя бы на этой неделе.
# 100.9-103.1: Выходные считать?
# 104.8-108.8: МИСТЕР И МИССИС СМИТ
# 109.0-111.7: Расскажите, как вы познакомились.
# 111.9-113.7: Это произошло в Колумбии.
# 113.9-115.1: В Боготе.
# 115.6-117.6: Пять лет назад.
# 117.8-119.4: Шесть.
# 119.6-121.6: Да, пять или шесть лет назад.
# 124.4-126.5: БОГОТА, КОЛУМБИЯ
# 127.4-129.5: ПЯТЬ ИЛИ ШЕСТЬ ЛЕТ НАЗАД
# 139.6-141.4: Эй, в чем дело?
# 141.6-143.2: Кто-то застрелил барракуду.
# 143.4-146.4: Полиция разыскивает туристов,
# которые путешествуют в одиночку.
# 152.8-154.8: Вы путешествуете один?
# 157.5-159.6: Сеньора, будьте добры,
# ваш паспорт.
# 164.1-165.7: Ваши документы.
# 168.0-169.4: Вы одна?
# 170.0-171.9: Нет.
# 173.4-176.0: Нет, нет, нет. "Эста бьен".
# 176.2-177.4: Она со мной.
# 187.5-189.4: Меня зовут Джейн.
# 190.5-191.9: А я Джон.
# 192.1-194.6: - Очень приятно.
# - Мне тоже.
# 197.5-199.0: Здесь никого.
# 199.2-201.6: - Чтобы нам везло.
# - Чтобы нам везло.
# 209.4-210.8: Потанцуем?
#
# === Сцена 2 (238.8 сек, 48 реплик) ===
# 314.5-316.6: Здравствуй.
# 316.8-319.4: Привет.
# 320.5-322.4: Доставка в номер.
# 322.6-324.3: Приготовил, что смог.
# 325.1-326.9: Спасибо.
# 330.1-332.0: Вкусно.
# 332.5-335.4: Пришлось козу доить,
# чтобы добыть тебе молока.
# 370.2-372.8: Подходите сюда,
# дамы и господа.
# 373.0-376.2: Милая девушка,
# не желаете испытать удачу?
# 376.4-377.8: Выиграете приз.
# 379.8-381.7: Давай?
# 384.1-386.1: Деньги.
# 388.2-390.8: Держать умеешь?
# 391.5-393.6: - Так?
# - Так.
# 396.6-399.4: - Нужно целиться.
# - Я целюсь.
# 400.0-401.8: Не смейся, убью!
# 403.5-405.0: Можно я?
# 411.8-414.1: Ну, хоть что-то мы выиграли?
# 414.3-416.1: Новичкам везет.
# 417.3-418.9: Я хочу еще.
# 419.0-420.6: Еще разок.
# 431.6-433.9: Где ты так научилась?
# 434.4-436.6: Новичкам везет.
# 439.0-442.0: Остановись, ты знаком
# с девчонкой всего полтора месяца.
# 442.2-446.3: Я влюбился. Она умна,
# сексуальна, раскованна.
# 446.5-447.9: У нее прекрасный вкус.
# 448.1-449.4: С ней интересно.
# 449.6-451.0: Она лучше всех на свете.
# 451.2-454.0: Мы с Глейдис поженились через
# два с половиной года после знакомства.
# 454.2-457.0: Нужно заложить фундамент
# в виде крепкой дружбы, брат мой.
# 467.4-470.2: А тебе не кажется,
# что все происходит слишком быстро?
# 470.5-472.9: Я никогда ничего
# не делаю, не подумав.
# 473.1-474.8: А чем он занимается?
# 475.0-476.7: Строительством.
# 476.9-478.4: Он крупный подрядчик.
# 478.6-482.5: Рухнет сервер на Уолл-Стрит,
# и она тут же мчится его чинить.
# 486.9-488.9: Она как Бэтмен для компьютеров.
# 489.1-492.7: Он влюблен так же, как и я,
# так что это прекрасно.
# 494.0-496.3: Да вы через полгода разбежитесь.
# 496.5-500.4: Эдди, я сделал ей предложение.
# 500.7-502.1: Что?
# 502.3-503.5: Я женюсь, Эдди!
# 503.8-505.4: Что? Я не слышу!
# 506.8-508.3: - Я женюсь!
# - Не слышу.
# 508.5-510.0: Хватит его бить.
# Он несет какой-то бред.
# 510.5-512.0: Мы женимся!
# 519.9-522.7: ПЯТЬ ИЛИ ШЕСТЬ ЛЕТ СПУСТЯ
# 551.5-553.3: Пора менять фильтры.
#
# === Сцена 3 (66.6 сек, 19 реплик) ===
# 553.5-555.2: Как тебе доктор Весли?
# 555.4-557.3: Он выглядел
# не слишком убедительно.
# 557.5-559.2: Да, верно.
# 559.4-560.9: И вопросы у него дурацкие.
# 562.1-564.5: И ездить к нему через весь город.
# 564.8-566.5: В самый час пик - четыре часа.
# 566.7-568.6: На фиг нам это надо?
# 569.7-571.4: Значит, вопрос решен, да?
# 571.6-573.4: Согласен.
# 576.4-577.5: Хорошо.
# 577.7-579.7: Ты не забыл, ужин в семь!
# 579.9-582.3: Да, я буду. Счастливо.
# 604.8-607.6: Если кто-то будет звонить,
# я у босса, ясно?
# 607.8-610.8: Меня вызывает сам.
# Хочет дать суперзадание.
# 611.0-612.2: Ты представляешь?
# 612.4-613.5: Ничего ты не представляешь.
# 613.7-616.4: Прости, милашка, притащи-ка
# мне кофейку, только сахару побольше.
# 616.5-617.8: Спасибо.
# 618.0-620.0: Привет!
#
# === Сцена 4 (104.2 сек, 17 реплик) ===
# 623.7-625.6: И куда это ты собрался?
# 625.8-628.2: Ну, я...
# 628.4-630.4: - Босс хотел меня видеть.
# - Конечно.
# 630.6-632.0: Он уже видит.
# 632.4-636.2: Малыш, даже те,
# кто проработал здесь 25 лет
# 636.4-638.0: не знают,
# как выглядит этот лифт изнутри.
# 638.2-639.8: Держи.
# 644.9-646.8: Это и есть задание?
# 647.0-648.9: А теперь уходи.
# 701.8-703.7: - Привет, детка.
# - Ты как раз вовремя.
# 703.9-705.6: Этот дождь меня достал.
# 708.4-710.9: Садовник забыл убрать косилку.
# 715.2-717.4: - Как работа?
# - Более-менее.
# 717.6-719.5: Я купила новые шторы.
# 719.7-721.4: - Правда?
# - Ага.
# 722.7-725.0: Ну?
# 725.0-727.9: Что скажешь?
#
# === Сцена 5 (19.3 сек, 8 реплик) ===
# 732.8-735.8: Зубами вырвала
# у одного плюгавого мужика.
# 736.0-739.0: Он в них первый вцепился,
# но я победила.
# 739.3-740.1: Ну, еще бы.
# 740.4-741.5: Шторы чуть зеленоваты,
# 741.6-743.9: так что придется сменить обивку дивана
# и купить новый ковер.
# 744.1-745.1: Может персидский?
# 745.3-747.9: А можно оставить старые шторы,
# и ничего менять не придется.
# 749.7-752.1: Мы же говорили об этом. Забыл?
#
# === Сцена 6 (54.8 сек, 7 реплик) ===
# 756.0-758.8: Я помню, что мы
# договорились немного подождать.
# 760.3-763.2: Если не нравится, можно и вернуть.
# 763.8-766.1: Прекрасно. Мне не нравится.
# 766.6-768.6: Привыкнешь.
# 769.9-771.1: М-да.
# 803.4-806.3: 0% годовых до марта.
# 808.6-810.9: Итак, вторая серия.
#
# === Сцена 7 (43.6 сек, 9 реплик) ===
# 811.0-814.1: На этот раз вы пришли один.
# Почему вы ко мне вернулись?
# 814.3-816.5: Я точно не знаю.
# 817.2-819.6: Чтобы было понятно, я люблю жену.
# 820.9-823.1: Хочу, чтобы она была счастлива.
# 823.3-826.0: Желаю ей добра.
# 826.6-830.1: Но бывают такие минуты...
# 847.4-849.4: - Милая, ты не...
# - Пять минут.
# 850.2-851.9: Так в чем проблема?
# 852.1-854.6: Гигантская пропасть разделяет нас.
#
# === Сцена 8 (46.3 сек, 13 реплик) ===
# 854.8-859.5: И, конечно, постоянные недомолвки
# еще больше отдаляют друг от друга.
# 860.3-861.8: Как это называется?
# 862.0-863.8: Семейная жизнь.
# 864.1-866.8: А почему вы не можете
# откровенно поговорить?
# 872.6-875.3: Все-таки им дали три звезды.
# 876.4-878.2: Что-то новенькое?
# 878.4-880.1: Ты что-то добавила?
# 881.8-883.7: - Да?
# - Горошек.
# 884.5-886.5: А, горошек.
# 888.0-890.3: Зеленый такой.
# 892.5-894.6: Ты не передашь мне соль?
# 894.8-896.7: Она посередине.
# 898.2-901.2: - Она посередине?
# - Да, между мной и тобой.
#
# === Сцена 9 (187.6 сек, 35 реплик) ===
# 905.9-908.9: - На сколько вы с ним честны?
# - Достаточно.
# 909.1-915.8: Просто я честна с ним,
# только у меня есть свои тайны,
# 916.0-917.8: как и у всех.
# 938.6-941.5: Господи. Как ты меня напугал.
# 941.7-943.1: Прости, дорогая.
# 943.4-946.8: Ты уезжаешь?
# 947.6-951.8: Какой-то дурачок обрушил сервер
# в юридической фирме в центре города.
# 955.7-957.7: Мы собирались к Колдманам.
# 958.0-959.8: - Я знаю.
# - И что?
# 960.0-961.9: Я приеду. Не волнуйся.
# 962.1-963.9: Это быстро.
# 971.8-973.2: Вам, наверное, кажется,
# 973.4-976.2: что вы единственный
# столкнулись с подобными проблемами.
# 976.4-980.9: Но такие же трудности испытывают
# миллионы пар во всем мире.
# 981.4-983.4: Ясно.
# 1021.6-1023.4: Самолет через час.
# 1024.1-1025.5: Хорошо.
# 1026.1-1027.3: Цитаты за 800.
# 1027.5-1029.9: На вопрос о возможности
# использования инсайдерской информации
# 1030.1-1031.8: для получения личной выгоды
# она ответила:
# 1031.9-1033.6: "Займусь-ка я лучше своими салатами".
# 1033.8-1034.9: - Марта Стюарт.
# - Марта Стюарт.
# 1035.1-1036.5: Да.
# 1060.3-1063.2: ДЛЯ СОТРУДНИКОВ
# 1064.8-1067.9: 40? Поддерживаю.
# 1069.3-1071.4: Какого черта?
# 1071.6-1074.2: Простите, куда здесь туалет подевался?
# 1074.4-1076.1: Черт подери.
# 1076.4-1078.7: Вы что, в покер играете?
# 1078.9-1080.7: Чужих не берем. Отвали!
# 1080.8-1082.1: А можно с вами, вы не против?
# 1082.3-1084.8: Какую часть слова "отвали"
# ты не расслышал?
# 1085.0-1088.2: Ребята, ну что вы такие?
# Будьте дружелюбнее.
# 1088.4-1090.6: - У меня есть наличка.
# - Что ты привязался?
# 1090.7-1093.6: Классная пушка. Ты крутой.
#
# === Сцена 10 (239.2 сек, 44 реплик) ===
# 1093.8-1096.4: Слушайте, вот видите,
# у меня кое-что есть.
# 1096.6-1099.2: Капуста. Если вам интересно.
# 1099.6-1102.0: Не хотите? Ну, как хотите.
# 1102.2-1104.8: Потому что я чужой?
# Понятно.
# 1105.0-1106.9: Слушайте, я хотел...
# 1107.0-1109.3: Классные шузы, брат.
# 1110.6-1112.2: Осторожнее.
# 1113.5-1115.8: А вот же у вас
# свободный стульчик. Можно?
# 1116.0-1117.4: Это стул Счастливчика.
# 1117.6-1119.6: Ну и где он этот ваш Счастливчик?
# 1119.8-1121.5: Еще не вернулся.
# 1121.6-1127.4: Тогда я здесь посижу,
# если не будете приставать.
# 1164.8-1167.4: - Чистое серебро.
# - О, здорово.
# 1167.6-1169.4: Чистое серебро.
# 1169.6-1172.0: Чтоб нам везло.
# 1172.3-1174.0: Клади в банк.
# 1174.7-1178.0: Молодец, молодец.
# 1178.2-1179.8: Ну, теперь держитесь!
# 1180.0-1182.3: 60 долларов?
# 1182.5-1184.9: - Давай.
# - Ишь как разошелся.
# 1186.3-1188.0: Выпьем!
# 1188.2-1190.5: Да здравствует покер!
# 1202.1-1203.5: Это еще что?
# 1203.7-1206.0: Прости, Счастливчик.
# Спасибо за игру, приятель.
# 1206.2-1207.3: Будет что вспомнить.
# 1207.5-1208.6: - Ты Счастливчик?
# - Да.
# 1208.8-1212.1: - Серьезно?
# - В чем дело, малыш? Ты ищешь работу?
# 1212.4-1214.9: Ты моя работа.
# 1228.9-1231.1: Пара дурацких троек.
# 1236.0-1238.0: - Ты плохой мальчик?
# - Да.
# 1243.0-1245.4: А знаешь, что бывает
# с плохими мальчиками?
# 1247.6-1249.7: - Их наказывают.
# - Накажи меня.
# 1255.0-1258.0: Зря ты продавал
# большие пушки плохим дядям.
# 1265.3-1266.9: Мистер Росин?
# 1268.3-1269.8: Мистер Росин?
# 1270.0-1271.4: Все хорошо?
# 1272.6-1274.4: Колдманы.
# 1279.1-1280.6: Он мертв!
# 1298.6-1299.9: Такси?
# 1320.2-1322.8: - Привет, милая.
# - Привет, любимый.
# 1322.9-1324.6: А я решила, тебя нет.
# 1325.2-1328.6: Да, я ходил в спорт-бар,
# сделал пару ставок на игру.
# 1328.8-1330.3: Да? Ну и как?
# 1331.2-1332.9: Удачно.
#
# === Сцена 11 (67.4 сек, 26 реплик) ===
# 1337.0-1340.2: - Добро пожаловать, соседи!
# - Добро пожаловать, соседи!
# 1340.4-1342.3: - Приветствую.
# - Рада тебя видеть.
# 1343.6-1345.0: Как у вас здорово!
# 1345.2-1346.3: Проходите, пожалуйста.
# 1346.5-1348.5: Давайте пальто.
# Чудесное платье!
# 1348.7-1350.7: Спасибо.
# 1351.8-1355.2: - Пойдем к девчонкам.
# - Не увлекайтесь там.
# 1355.7-1359.3: - Хочешь сигар?
# - Нет, нет, нет, я не курю.
# 1359.6-1361.9: В здоровом теле - здоровый дух.
# Так Сьюзи говорит.
# 1362.1-1364.2: - И она права.
# - Ну, ты ведь не безгрешен.
# 1364.4-1365.4: Ну, знаешь...
# 1365.5-1368.9: - Хочешь что-нибудь выпить?
# - Да, я бы не отказалась от Шердоне.
# 1369.1-1371.0: Шердоне? Замечательно. Девочки!
# 1371.1-1372.5: Шердоне.
# 1373.1-1376.1: Я пойду к бару, поздороваюсь.
# 1377.6-1378.8: - Привет, ребята.
# - Привет, Джон.
# 1379.0-1380.6: - Скотч.
# - Да, сэр.
# 1381.0-1384.1: Джонни, как дела?
# Где ты держишь свои накопления?
# 1384.3-1386.4: Я все свои бабки
# храню в чулке.
# 1387.7-1389.6: Да, Чак получил повышение.
# 1389.8-1391.5: О, господи, какая прелесть.
# 1391.6-1392.7: Поздравляю.
# 1392.9-1395.4: Теперь мы можем купить
# еще кое-что из кухонной мебели.
# 1395.7-1397.7: Ну что же это такое?
# 1398.4-1400.3: Ну, хоть плащ надевай.
# 1400.5-1404.4: Знаете, что...
# Вы не подержите ее?
#
# === Сцена 12 (161.7 сек, 26 реплик) ===
# 1404.5-1407.0: Пожалуйста, мне нужно
# почистить кофточку.
# 1407.2-1409.7: Я... Ну, хорошо.
# 1409.9-1412.6: - Прошу вас.
# - Привет, малышка.
# 1412.8-1414.5: Ну, надо же так.
# 1415.5-1417.9: А вы знаете, дети все чувствуют.
# 1418.4-1420.6: Ты ей нравишься.
# 1432.8-1437.0: У тебя платье сегодня
# очень красивое.
# 1438.2-1440.0: Спасибо.
# 1527.0-1528.6: Доброе утро, мистер Смит.
# 1528.8-1530.3: В Атланте опять неприятности.
# 1530.4-1531.9: Как всегда. Что у вас?
# 1532.0-1534.8: Ваш посадочный талон
# и чеки за такси.
# 1535.0-1537.0: Выплюньте эту жвачку.
# 1537.2-1538.6: А салфетку?
# 1538.8-1540.5: - И ваш счет из гостиницы.
# - Спасибо.
# 1540.7-1543.2: Только аккуратно.
# Смотрите не потеряйте.
# 1543.6-1546.6: - Вышли данные по новому объекту.
# - Прекрасно, Луи, я посмотрю.
# 1546.8-1547.6: Спасибо.
# 1547.8-1550.4: - Эдди сейчас здесь?
# - Дверь не заперта.
# 1551.3-1552.5: Здарово, приятель.
# 1552.6-1554.8: - Как дела?
# - Все по-прежнему.
# 1555.0-1556.6: Много заказов.
# 1557.2-1560.0: Джонни, приглашаю тебя на вечеринку.
# 1560.2-1563.2: У меня дома. Барбекю.
# Никаких дам, только парни.
# 1563.4-1564.6: Будет круто.
# 1564.8-1566.2: Мне нужно поговорить с женой.
#
# === Сцена 13 (215.4 сек, 44 реплик) ===
# 1566.8-1568.7: Дать тебе сотовый?
# 1568.9-1571.9: Ты будешь звонить ей всякий раз,
# когда захочешь задницу почесать?
# 1572.1-1574.0: Главное, чтобы она не была против.
# 1575.0-1576.5: А ты живешь у матери.
# 1576.7-1579.3: Ну и что тут такого?
# Она у меня вообще высший класс.
# 1579.5-1582.0: И я ей не докладываюсь,
# когда хочу что-то сделать.
# 1582.4-1584.3: Готовит, убирает,
# бутерброды мне делает.
# 1584.4-1586.6: По-твоему, я зря к ней переехал?
# 1601.6-1603.4: Пароль?
# 1603.5-1604.5: Джон Смит.
# 1604.7-1606.1: Пароль принят.
# 1608.8-1611.6: - Здравствуй, Джон.
# - Доброе утро, Атланта.
# 1611.8-1615.6: На этой неделе ты работал в поте лица,
# но у нас задача высшего приоритета,
# 1615.8-1617.0: и мне нужен ты.
# 1617.3-1621.6: Имя объекта Бенджамин Данс,
# по кличке Танк.
# 1621.9-1623.2: Прямая угроза конторе.
# 1623.4-1626.7: Его должны передать людям из
# разведуправления Министерства Обороны.
# 1626.8-1629.0: Агенты доставят объект к вертолету.
# 1629.3-1632.4: Это произойдет в шестнадцати километрах
# к северу от мексиканской границы.
# 1632.5-1635.3: Ты должен сделать так,
# чтобы передавать было некого.
# 1635.5-1637.1: И это Танк?
# 1663.7-1665.3: У нас сложная ситуация.
# 1665.4-1667.8: Конкуренты спят и видят,
# как бы нас утопить.
# 1668.0-1670.8: Поэтому я хочу, чтобы
# этим делом занялась ты лично.
# 1671.0-1672.9: - Объект?
# - Бенджамин Данс.
# 1673.1-1675.1: Я уже переслал в контору
# все его данные.
# 1675.3-1677.6: Задание нужно выполнить
# быстро, чисто и на все сто.
# 1677.8-1678.7: Да, сэр.
# 1686.7-1689.9: - Доброе утро.
# - Доброе утро.
# 1691.9-1695.1: Результаты вчерашней операции.
# Цель уничтожена, объект под стражей.
# 1695.4-1696.3: Завтра мы его вытащим.
# 1696.6-1698.8: Привезли два ящика ДЖ-40, гранатометы.
# 1699.0-1700.3: Закажи еще десять.
# 1700.5-1702.0: Слушай, Джесс.
# 1702.1-1705.2: Объект Бенджамин Данс,
# по кличке Танк.
# 1705.4-1707.0: - Ты серьезно?
# - Да.
# 1707.2-1710.0: Объект перебрасывают через границу
# в федеральную тюрьму.
# 1710.2-1713.5: Провести операцию можно только здесь,
# неподалеку от границы.
# 1713.8-1718.3: Нужны спутниковые снимки каньона
# и прогноз погоды на ближайшие три дня.
# 1719.6-1723.4: Конвой доставит объект к вертолету
# на заброшенном аэродроме в пустыне.
# 1727.7-1729.6: Кругом одна пустыня.
# 1760.9-1764.0: - Жду добро.
# - Система включена. Работаем.
# 1778.0-1780.7: Третий, Третий, говорит Воздух,
# я на полпути.
# 1780.8-1782.3: Вас понял.
#
# === Сцена 14 (187.0 сек, 20 реплик) ===
# 1818.7-1820.4: Только не это!
# 1827.9-1831.7: - Джесс, ты видишь?
# - Да, попытка срыва операции?
# 1834.2-1835.8: Начался обратный отсчет.
# 1836.0-1837.6: Они что, вошли в зону поражения?
# 1837.8-1839.6: Этот идиот нарушил нам все планы.
# 1850.5-1852.4: Неплохо.
# 1877.2-1879.1: Это гражданский.
# 1891.6-1894.5: Что нам удастся сыграть
# на этом тромбоне?
# 1898.4-1900.3: У него какое-то оружие!
# 1900.5-1902.1: Он не гражданский!
# 1905.4-1907.4: О, черт!
# 1907.6-1908.8: Засранец!
# 1918.6-1921.0: Объект в зоне проведения операции.
# 1943.2-1945.6: Да, впечатляющая вещица.
# 1953.5-1954.9: Отмена, отмена!
# 1994.8-1997.0: По-моему, я на этой
# операции засветился.
# 1997.2-1999.4: - У тебя так было?
# - Насколько я знаю, нет.
# 1999.6-2001.1: Ну ладно. У меня проблемы.
# 2001.4-2003.1: Ты его разглядел?
# 2003.3-2005.6: Чуть-чуть. Весит килограммов 45.
#
# === Сцена 15 (19.8 сек, 8 реплик) ===
# 2005.8-2007.5: Может, он филиппинец.
# 2008.4-2010.2: Я не уверен, что это "он".
# 2012.4-2015.0: Тебя чуть не завалила
# какая-то девчонка?
# 2015.5-2017.0: Думаю, да.
# 2017.3-2018.8: Она профи.
# 2019.4-2021.6: Ну, тогда не проблема ее найти.
# 2021.8-2024.0: Среди наемниц
# не так уж много цыпочек.
# 2024.2-2025.7: Вы будете десерт?
#
# === Сцена 16 (66.8 сек, 25 реплик) ===
# 2025.8-2027.6: - А что у тебя есть?
# - Мороженое.
# 2027.8-2030.0: Мороженое? Звучит заманчиво.
# А какое есть?
# 2030.2-2032.4: - Шоколадное, ванильное.
# - По отдельности я их не люблю.
# 2032.6-2035.6: Может быть, если их смешать,
# то получится то, что нужно.
# 2035.8-2039.0: Как думаешь? Только ты уж
# не по одному шарику сделай.
# 2040.2-2042.0: - Я постараюсь.
# - Шикарно.
# 2042.2-2045.6: Постарается. Ты слышал?
# Если меня такая завалит, я не против.
# 2046.6-2049.1: Что-нибудь еще кроме
# ее весовой категории у тебя есть?
# 2049.3-2050.3: Лэптоп.
# 2050.5-2052.4: Прости, но даже я
# тебя не всегда понимаю.
# 2052.6-2054.1: - Лэптоп.
# - Ясно, лэптоп.
# 2054.3-2055.8: - Я хочу знать, что это за тварь.
# - Не спеши.
# 2056.0-2057.0: - Дай мне запись.
# - Джейн.
# 2057.2-2058.1: Принеси запись!
# 2058.4-2060.3: - Джейн!
# - Что?
# 2060.5-2062.5: Это отец.
# 2068.4-2070.4: Объект остался у продавцов.
# 2070.6-2071.9: Дверца закрылась.
# 2072.1-2073.8: У нас нет права на ошибку.
# 2074.0-2075.2: Вмешался посторонний.
# 2075.4-2077.6: Мы не оставляем свидетелей,
# он мог тебя засветить.
# 2077.8-2079.6: Ты знаешь правила.
# 2080.1-2083.9: У тебя 48 часов.
# Ты должна подчистить хвосты, Джейн.
# 2084.6-2086.6: С удовольствием, сэр.
# 2089.7-2092.6: У нас новая цель.
# Давайте выясним, кто он.
#
# === Сцена 17 (122.4 сек, 23 реплик) ===
# 2097.4-2099.3: И что же ты им делал?
# 2099.5-2101.3: Тушил им костер?
# 2101.7-2103.7: Купи себе новый.
# 2104.0-2106.8: Прежнему хозяину
# он был очень дорог.
# 2107.4-2108.7: И кто он?
# 2108.9-2111.6: Знаешь, Гвен,
# я думал, ты мне это скажешь.
# 2114.7-2117.3: Но зачем тебе знать его имя?
# 2117.5-2120.2: Кто-то потерял хорошую вещь,
# хочу вернуть.
# 2120.4-2122.7: - Привет, Фил.
# - Привет, Джон.
# 2130.3-2132.4: Посмотрим.
# 2132.6-2136.3: Чип памяти заменен на более мощный.
# 2138.4-2140.3: Сделан в Китае.
# 2140.5-2142.9: Импортирован компанией "Дайнамикс".
# 2143.1-2146.4: В розницу был продан...
# 2146.9-2149.6: Я смотрю раздобыть
# адрес покупателя.
# 2151.7-2154.6: Точно. Имен нет, только адрес.
# 2154.8-2159.1: Лексингтон авеню, 570,
# 50-й этаж, блок "А".
# 2159.3-2160.8: Нью-Йорк.
# 2161.0-2162.8: Ты знаешь это место?
# 2191.0-2192.7: Блок офисов "А"
# 2193.9-2195.9: Агентство по подбору персонала
# "Ай-Темп". Джейн Смит
# 2197.5-2199.8: Черт, как же это может быть?
# 2217.4-2219.7: Ты не могла бы мне сделать кофе?
#
# === Сцена 18 (192.0 сек, 20 реплик) ===
# 2240.1-2242.3: Джейн, это твой муж.
# 2243.9-2246.6: Вернулся из Атланты,
# спрашивает на счет ужина.
# 2248.6-2252.1: Скажи ему, ужин будет в семь.
# 2252.4-2255.4: Джон, она говорит, ужин - в семь.
# 2255.9-2257.9: Как всегда.
# 2325.2-2327.4: Ты вовремя.
# 2327.6-2329.4: Как всегда.
# 2334.2-2336.9: - Какой приятный сюрприз.
# - Надеюсь.
# 2337.1-2339.6: - Что так рано?
# - Я соскучился.
# 2341.0-2343.1: Я по тебе тоже.
# 2343.4-2345.4: - Приступим?
# - Да.
# 2359.1-2361.4: По какому случаю торжество?
# 2361.6-2363.6: Есть особый повод.
# 2394.2-2396.6: Запеченное мясо! Мое любимое!
# 2400.5-2402.4: Позволь мне, дорогая.
# 2402.8-2404.7: Ты, наверное, устала.
# 2405.0-2406.8: Спасибо.
# 2407.2-2409.0: Не за что.
# 2423.5-2424.9: Как на работе?
# 2428.5-2432.2: Знаешь, возникли
# проблемы с комиссионными.
#
# === Сцена 19 (71.4 сек, 10 реплик) ===
# 2432.4-2434.5: - Да что ты?
# - Да.
# 2435.0-2437.5: Разбираемся с другой фирмой.
# 2438.7-2440.4: - Фасоль будешь?
# - Нет, спасибо.
# 2441.0-2443.0: Ты должен попробовать.
# 2447.0-2449.3: Я думаю, все у вас наладится.
# 2449.4-2451.0: Обязательно.
# 2451.6-2453.8: Обещаю.
# 2461.1-2463.7: Мое самое любимое блюдо.
# 2463.8-2465.9: Дорогая, ты не передашь соль?
# 2501.7-2503.8: Ты что-то добавила?
#
# === Сцена 20 (191.8 сек, 33 реплик) ===
# 2520.2-2522.4: Как в Атланте?
# 2523.3-2526.6: Тоже небольшие проблемы.
# Кое-что не сходится.
# 2527.9-2530.3: - Серьезный вопрос?
# - Жизни и смерти.
# 2530.5-2532.8: - Вина?
# - Да.
# 2554.0-2555.9: - Я уберу.
# - Я уберу.
# 2568.1-2570.0: Джейн?
# 2573.0-2574.9: Милая?
# 2582.6-2584.8: Джейн?
# 2595.7-2597.5: Как я могла быть такой дурой?
# 2608.1-2609.7: Джейн?
# 2609.9-2611.5: Джейн?
# 2629.7-2631.3: Господи!
# 2639.7-2642.3: Стой! Нет, нет, нет, нет.
# Я случайно.
# 2642.4-2644.4: Милая, это была случайность.
# 2644.6-2646.5: Джейн, останови машину сейчас же!
# 2649.9-2652.0: Джейн,
# ты все принимаешь близко к сердцу.
# 2653.0-2655.2: Давай не будем увлекаться.
# 2655.5-2657.2: Злость тебе не к лицу, милая.
# 2657.4-2658.9: - Давай все обсудим.
# - Черт.
# 2659.1-2660.4: Остановись.
# 2660.6-2662.0: Джейн, остановись.
# 2662.2-2664.0: Остановись!
# 2665.9-2667.6: А ну, стой!
# 2672.3-2674.0: Нужно поговорить!
# 2683.5-2685.8: Иду, иду! Кто там?
# 2686.4-2687.8: Открывай.
# 2691.0-2692.5: Кто это тебя разукрасил?
# 2692.6-2694.4: Моя жена.
# 2699.9-2701.9: - Она хотела меня убить.
# - Ну да, конечно.
# 2702.1-2704.5: Глэдис тоже пыталась меня убить,
# только машину пожалела.
# 2704.7-2707.9: А Джейн поступила, как настоящий мужик.
# Они все любят нас мучить.
# 2708.1-2710.3: Изощренно. Медленно, по-садистски.
# 2710.5-2711.9: Норовят укусить побольнее.
#
# === Сцена 21 (69.8 сек, 26 реплик) ===
# 2712.1-2714.6: Знаешь, как я из-за нее страдал?
# Переживал, мучался.
# 2714.8-2717.0: А сейчас я свободен.
# Все время хожу на свидания с кем хочу.
# 2717.2-2718.7: И самое главное,
# на мозги никто не капает.
# 2718.9-2719.8: Ты живешь с мамой.
# 2720.0-2722.6: Потому что мама - единственная
# женщина, которой я доверяю.
# 2726.8-2728.7: - Это просто невероятно.
# - Я знаю, о чем ты думаешь.
# 2728.9-2733.0: И ты прав! Если она в одном обманула,
# значит, может соврать в любой момент.
# 2733.2-2736.3: Как шпионка, она должна
# из людей информацию выкачивать.
# 2736.5-2740.8: Французская Ривьера, яхта,
# иранский принц.
# 2741.0-2744.6: Ей нужно с ним сблизиться,
# и так далее. Отвратительно.
# 2745.5-2746.8: Что?
# 2747.0-2748.5: Что ты сказал?
# 2748.7-2751.1: Что? Твой муж - наемный убийца?
# 2751.4-2753.5: Этого не может быть.
# 2754.8-2756.5: Неужели?
# 2756.7-2758.9: Может, у них с самого начала
# план был такой?
# 2759.1-2760.4: Операция наблюдения за Джонни.
# 2760.6-2763.3: Вдруг тебя шесть лет
# пытались расколоть, и вот...
# 2763.5-2764.7: Задание выполнено.
# 2767.2-2769.7: Ну, хорошо.
# 2769.9-2771.7: Подведем баланс.
# 2771.9-2773.9: - Ты его не любишь?
# - Нет.
# 2774.1-2775.5: И ты его убьешь.
# 2775.7-2777.8: В этом деле лучше тебя нет.
# 2778.0-2779.8: Спасибо.
# 2780.0-2781.9: И все будет кончено.
#
# === Сцена 22 (211.8 сек, 37 реплик) ===
# 2787.5-2791.0: Джонни, я понимаю, ты сконфужен,
# но это же я, твой друг Энди.
# 2791.4-2793.6: Наши об этом не узнают.
# Я буду нем, как рыба.
# 2793.8-2797.1: Я понимаю, что люди, с которыми она
# работает, смеялись над тобой шесть лет.
# 2797.4-2799.2: Ну, так что? Наплевать на них,
# ты им отомстишь.
# 2799.4-2802.6: Слушай, считай, что 150 страниц
# книги уже написаны.
# 2802.8-2806.4: И на этих 150-ти страницах
# Джонни водили за нос.
# 2806.6-2809.2: Но финальные 10 страниц
# можешь написать ты.
# 2809.4-2811.0: Последнее слово за тобой.
# 2813.3-2816.8: Отлично поговорили, приятель,
# я в восторге. Я тобой горжусь!
# 2817.0-2818.5: Я одолжу?
# 2818.7-2820.0: И ход твоих мыслей мне нравится.
# 2820.5-2822.5: - Сделаю это утром.
# - Конечно.
# 2823.6-2825.0: - Ты в порядке?
# - Да.
# 2825.1-2827.7: - Хорошо. Спокойной ночи.
# - Спокойной ночи.
# 2842.4-2844.5: Ты его не любишь.
# 2844.7-2847.0: - Спокойной ночи.
# - Спокойной ночи.
# 2847.2-2849.9: Спокойной ночи, мам!
# 2895.5-2897.4: Итак, девочки, за дело.
# 2897.5-2901.0: Все из карманов.
# Квитанции, мусор. И повнимательнее.
# 2924.8-2927.2: - Это что?
# - Ваш медовый месяц.
# 2927.4-2928.7: Я спрашиваю, что вы здесь делаете?
# 2928.9-2932.4: - Ищем информацию об объекте.
# - Так, в этой комнате закончили.
# 2932.6-2933.9: Спасибо.
# 2934.0-2939.8: Обещаешь ли ты уважать и любить,
# пока смерть не разлучит вас?
# 2942.9-2946.6: Я, Джон, беру Джейн
# в свои законные жены
# 2946.8-2949.6: и обещаю любить...
# 2954.8-2956.9: Что происходит, миссис Смит?
# 2958.4-2960.1: У нас уборка.
# 2968.2-2970.4: Привет, сосед.
# 2977.4-2980.1: Ох, ты!
# И как это я раньше здесь не бывал?
# 2980.4-2981.4: Класс!
# 2981.6-2983.0: Впечатляет?
# 2983.2-2984.6: О, да!
# 2986.1-2989.6: - Шикарные полы! Что это? Тик?
# - Красный дуб, Мартин, красный дуб.
# 2990.6-2995.6: Так ты в этом году еще
# и приз турнира "Гольф Мастерс" выиграл.
# 2995.8-2997.1: - Опять.
# - Опять.
# 2997.3-2999.3: А в следующем году тебе повезет.
#
# === Сцена 23 (50.3 сек, 15 реплик) ===
# 3029.1-3030.8: Дрянь!
# 3036.0-3038.3: Нужно составить
# его психологический портрет.
# 3038.8-3041.1: Все доступные средства хороши.
# 3041.3-3044.6: Прослушка телефонов, контроль за
# кредитками, сканирование радиочастот.
# 3044.8-3046.5: А образец голоса?
# 3049.4-3051.3: Привет, вы позвонили Джон и Джейн Смит,
# 3051.5-3054.9: мы не можем ответить на ваш звонок,
# оставьте сообщение, мы вам перезвоним.
# 3055.6-3056.8: Он должен быть в базе.
# 3057.0-3058.8: Как кто? Джон Смит?
# 3062.3-3064.4: Найдем.
# 3064.6-3066.4: - Джейн?
# - Что?
# 3067.3-3068.9: Я его уже нашла.
# 3069.1-3071.1: - Где?
# - Здесь.
# 3074.4-3076.7: Сработал один из датчиков.
# 3076.9-3079.4: Начато сканирование этажей.
#
# === Сцена 24 (14.6 сек, 5 реплик) ===
# 3082.8-3085.3: А я ведь просила
# не беспокоить меня на работе.
# 3085.5-3087.1: Но ты все еще миссис Смит.
# 3087.3-3090.1: Сколько таких
# миссис Смит в нашей стране?
# 3091.0-3094.0: Осторожнее, могу нажать
# на курок в любой момент, солнышко.
# 3094.1-3097.4: Сомневаюсь. Ты никогда не наберешься
# смелости так поступить.
#
# === Сцена 25 (106.9 сек, 15 реплик) ===
# 3099.2-3102.0: Предупреждаю.
# Ты должна исчезнуть.
# 3102.2-3103.9: - Нет.
# - Сейчас же.
# 3104.8-3107.0: Ты и вправду думаешь,
# что я пойду на это?
# 3107.2-3109.4: Ты могла бы лучше
# изучить меня за пять лет.
# 3109.6-3111.7: Шесть. Я не исчезну.
# 3112.2-3113.8: В зоне чисто.
# 3115.4-3118.2: Помни, в любой момент.
# 3120.2-3121.7: Эвакуация по плану "С".
# 3126.4-3130.6: Внимание всем сотрудникам.
# Немедленная эвакуация.
# 3130.8-3132.9: Начинаем обратный отсчет.
# 3135.1-3137.5: Немедленная эвакуация!
# 3147.7-3149.2: Все по местам!
# 3160.7-3162.4: Внимание, огонь!
# 3201.6-3203.8: Трусливая курица!
# 3204.1-3206.1: Придурок!
#
# === Сцена 26 (128.0 сек, 39 реплик) ===
# 3212.1-3214.5: Ты держал ее на прицеле
# и не смог выстрелить?
# 3214.7-3216.2: Джонни, у нас и так полно проблем,
# 3216.4-3219.1: а теперь из-за твоей мягкотелости
# их стало еще больше.
# 3219.5-3221.8: Они тебя в покое не оставят.
# 3223.1-3225.2: И попытаются напасть на мой дом.
# 3225.4-3227.0: Эдди, лучше помоги мне.
# 3227.3-3229.3: Ты хочешь разворошить осиное гнездо.
# 3229.5-3231.0: Ты просто сумасшедший.
# 3231.3-3233.5: Тебе дали 48 часов.
# 3233.7-3236.7: Сколько еще осталось? 23? 22?
# 3236.9-3238.3: 18 с минутами.
# 3238.5-3240.9: Значит через 18 часов
# с нами будет покончено?
# 3241.1-3242.8: - Эдди?
# - Мама!
# 3243.0-3246.2: Мы ждем нападения!
# Я тебя чуть не прикончил сейчас!
# 3246.4-3248.4: Не высовывайся, пожалуйста!
# 3248.6-3251.4: - Я и не собиралась.
# - Я не могу так жить.
# 3251.6-3253.3: Меня все это уже достало.
# 3253.5-3255.2: Ты должен прикончить эту дрянь.
# 3255.4-3256.8: Я сам разберусь со своей женой.
# 3257.0-3258.3: Она тебе не жена, она твой враг.
# 3258.5-3260.1: И, может, поджидает нас в засаде.
# 3260.3-3263.3: Эдди, нашел.
# 3265.0-3266.6: Ну, хоть что-то.
# 3266.8-3268.6: Кажется, ты обнаружил их логово.
# 3274.2-3275.5: Агентство "Блекбоул".
# 3275.7-3277.4: Я звоню из компании "Ай-Темп".
# 3277.6-3279.6: Как продвигаются работы
# в новом пентхаусе?
# 3279.8-3282.5: Ударными темпами.
# Спасибо, что не забываете.
# 3309.5-3312.0: Говорит охрана.
# Какие-то проблемы с лифтом, сэр.
# 3312.3-3315.2: Если хотите, я пришлю механика,
# чтобы он посмотрел, в чем там дело.
# 3315.4-3317.9: Не торопитесь.
# Мне здесь комфортно.
# 3318.3-3320.4: Комфортно, говоришь?
# 3321.0-3322.9: Джейн?
# 3323.8-3325.8: Это ты, любимая?
# 3326.3-3329.7: Первое предупреждение, Джон.
# Лучше исчезни.
# 3330.0-3332.2: Ты же знаешь, я никуда не поеду.
# 3332.7-3336.0: Только ты, пожалуйста, не забывай,
# что ты заперт на высоте 70-го этажа
# 3336.2-3338.6: в стальной коробке,
# и под тобой пустота.
# 3338.8-3340.2: Значит это ловушка.
#
# === Сцена 27 (52.1 сек, 20 реплик) ===
# 3340.4-3342.0: Он в лифте номер три.
# 3342.2-3344.5: У тебя ничего не выйдет.
# 3344.7-3347.6: Потому что ты постоянно
# меня недооцениваешь.
# 3349.0-3350.3: Да что ты!
# 3350.5-3352.1: Ты не представляешь, кто я.
# 3352.3-3354.8: И ты понятия не имеешь,
# на что я способен.
# 3355.8-3357.6: Попробуй продемонстрировать.
# 3357.8-3359.3: Одну минуту.
# 3359.6-3361.6: Замаскированный заряд
# на тросе противовеса
# 3361.8-3364.4: и еще два на основном
# и запасном тормозах.
# 3364.6-3365.9: Правильно?
# 3366.1-3368.5: - Он нашел их!
# - Я поняла.
# 3368.6-3371.9: А основной заряд с главного троса
# ты тоже снял?
# 3374.2-3377.5: Так что, лучше исчезни сам.
# Выбирайся из города, Джон,
# 3377.7-3380.5: а иначе тебя ждет долгое,
# но очень быстрое падение.
# 3382.4-3383.8: Ну, хорошо.
# 3384.0-3385.5: Я сдаюсь.
# 3386.2-3388.0: Взрывай.
# 3389.0-3390.5: Что?
# 3390.7-3392.5: Давай, взрывай.
#
# === Сцена 28 (235.9 сек, 38 реплик) ===
# 3392.7-3394.2: Думаешь, я этого не сделаю?
# 3394.4-3396.4: У тебя духу не хватит.
# 3397.3-3399.2: Ну, хорошо.
# 3399.9-3403.5: Пять, четыре...
# Скажешь что-нибудь?
# 3403.7-3405.5: Шторы были ужасными.
# 3406.1-3407.9: Прощай, Джон.
# 3418.5-3419.9: В чем дело?
# 3420.1-3421.5: А что?
# 3421.6-3423.2: Ты же сказала "прощай".
# 3458.4-3460.1: Джейн?
# 3527.3-3529.6: Мадам?
# 3529.9-3533.0: Я заготовил несколько фраз
# для нашей встречи.
# 3533.4-3538.1: "А я тут пролетал мимо", "Эй, куколка,
# спасибо, что прокатила на лифте".
# 3538.4-3539.9: Забавно.
# 3540.1-3542.1: Так что ты решил?
# 3542.4-3544.5: Я хочу развестись.
# 3545.0-3546.4: Впечатляет.
# 3546.6-3548.5: Здесь же ты сделал мне предложение.
# 3548.7-3550.7: - Явная симметрия.
# - Ваше пальто, сэр.
# 3552.4-3554.4: - Могу я присесть?
# - Нет.
# 3569.5-3572.2: - Шампанское, сэр?
# - Нет, шампанское для праздников.
# 3572.4-3573.8: Давайте Мартини.
# 3574.0-3575.8: Мне хватит, спасибо.
# 3579.4-3581.3: Так чего же ты хочешь?
# 3582.3-3584.7: У нас возникла проблема, Джейн.
# 3585.8-3587.9: Ты мне смерти желаешь.
# 3588.2-3590.7: Да и меня твое благополучие
# мало заботит.
# 3590.8-3592.5: Так что нам делать?
# 3593.8-3595.5: Устроим перестрелку?
# 3595.7-3597.3: Кому повезет?
# 3597.4-3598.8: Опозориться не хочется.
# 3599.0-3601.7: Ведь после твоей смерти
# меня наверняка попросят удалиться.
# 3606.7-3608.1: Потанцуй со мной?
# 3610.6-3612.1: Ты не танцуешь.
# 3612.4-3614.4: Это была часть моей легенды, дорогая.
# 3614.6-3616.7: А твоя лень - тоже часть легенды?
# 3624.0-3626.0: У нашей истории будет хэппи-энд?
# 3626.2-3628.6: Хэппи-энд оставляет
# чувство незаконченности.
#
# === Сцена 29 (49.6 сек, 11 реплик) ===
# 3650.4-3652.2: Удовлетворен?
# 3652.4-3653.8: Пока еще нет.
# 3661.2-3663.3: Это твой друг, солнышко.
# 3680.7-3682.7: Почему у нас ничего не вышло?
# 3682.9-3686.4: Потому что у каждого была
# своя жизнь, или ложь всему виной.
# 3686.6-3688.3: У меня есть теория.
# 3688.5-3690.9: - Она все объясняет.
# - Не терпится услышать.
# 3691.3-3692.6: Это твоя вина.
# 3692.7-3694.4: Ты провокатор.
# 3695.4-3697.5: Ты подошла к семейной жизни,
# как к очередному заданию,
# 3697.7-3700.0: которое нужно подготовить и выполнить.
#
# === Сцена 30 (197.8 сек, 34 реплик) ===
# 3700.2-3701.8: А ты этого избежал.
# 3702.2-3704.8: Я ведь был
# для тебя всего лишь прикрытием.
# 3705.0-3706.7: Кто тебе такое сказал?
# 3708.0-3709.7: А разве нет?
# 3709.9-3711.5: А я для тебя?
# 3717.6-3719.3: Мне нужно... Прости.
# 3720.4-3722.2: Там нет выхода, Джейн.
# 3726.7-3729.1: Не поддавайся, Джон, она врет.
# 3733.1-3735.2: Не поддавайся ей.
# 3765.9-3768.1: У вас там что-то тикает, сэр.
# 3773.0-3775.6: Назад, назад, назад!
# 3780.6-3782.3: Лимузин, сэр.
# 3797.9-3799.5: Джейн Смит.
# 3799.6-3801.4: Ты второй раз попыталась меня убить.
# 3801.6-3803.0: Подумаешь, маленькая бомбочка.
# 3803.2-3806.0: Я сейчас еду домой и собираюсь
# сжечь все, что покупал тебе.
# 3806.2-3807.9: Я тебя опережу, милый.
# 3823.8-3825.4: Ты уже там?
# 3825.6-3828.9: Когда мы познакомились,
# о чем ты подумала?
# 3829.1-3830.5: Сначала ты.
# 3831.4-3833.2: Я подумал,
# 3836.2-3839.0: ты красива,
# как рождественское утро.
# 3840.2-3842.8: Словами всего не скажешь.
# 3843.4-3845.8: Зачем ты мне это рассказываешь?
# 3846.5-3849.4: Просто в конце
# начинаешь думать о начале.
# 3852.4-3854.9: Я решил, ты должна знать.
# 3857.5-3859.8: Теперь твоя очередь.
# 3861.4-3863.6: Я решила,
# 3869.4-3872.8: что никогда еще не получала
# заказ на такого красавца.
# 3877.4-3879.6: - Для тебя это была работа?
# - Только работа.
# 3879.8-3881.9: - С самого начала?
# - Холодный расчет.
# 3883.6-3885.8: Спасибо за откровенность.
# 3888.8-3891.7: - Ну ладно.
# - Ладно.
# 3896.2-3898.0: Черт.
#
# === Сцена 31 (174.0 сек, 11 реплик) ===
# 3939.8-3941.6: Привет, Джон!
# 3941.8-3943.1: Привет, Билл!
# 3943.3-3945.7: - У тебя все в порядке?
# - Да.
# 3945.9-3947.4: Ну, хорошо.
# 3949.7-3954.0: Да, кстати, Джон, может быть,
# ты не заметил, но ты заехал на тротуар.
# 3954.4-3955.8: Да, спасибо, Билл.
# 3955.9-3957.4: Ладно, спокойной ночи.
# 3957.6-3959.1: Спокойной ночи.
# 3998.1-4000.5: Вот тварь!
# 4008.5-4010.1: Черт.
# 4111.8-4113.8: Ты еще жив, любимый?
#
# === Сцена 32 (232.5 сек, 12 реплик) ===
# 4185.9-4188.5: Стреляешь ты так же плохо,
# как готовишь.
# 4190.7-4193.1: Неужели тебе за это еще и платят?
# 4226.7-4228.8: Вставай, милая.
# 4229.5-4231.4: Иди к папочке.
# 4239.2-4241.4: Ну и кто из нас папочка?
# 4327.4-4329.7: Я не могу.
# 4332.0-4334.7: Ну, уж нет, давай!
# 4335.2-4337.4: Давай!
# 4338.6-4340.6: Тебе хочется,
# 4340.9-4342.9: ты и стреляй.
# 4413.5-4415.8: Ну, здравствуй.
# 4416.2-4418.4: Ты вернулась.
#
# === Сцена 33 (237.6 сек, 38 реплик) ===
# 4428.0-4430.0: - Да?
# - У вас все в порядке?
# 4430.1-4433.3: - Мы услышали жуткий грохот.
# - Да нет, у нас все хорошо.
# 4433.5-4436.4: Точно все нормально?
# 4436.6-4438.7: Да, лучше не бывает.
# 4440.2-4441.6: О, класс!
# 4441.8-4444.4: - Вы случайно...
# - Сьюзи и Мартин, офицеры.
# 4444.5-4446.9: Похоже, вы ремонт затеяли.
# 4447.0-4449.2: Ложная тревога.
# 4455.5-4458.0: Еще пять минут, мам.
# 4460.8-4464.0: Джейн Смит. 400 тысяч долларов.
# 4469.4-4473.6: Да, заманчиво, но я не вылезу
# из кровати меньше, чем за полмиллиона.
# 4473.9-4477.0: Джон Смит. 400 тысяч долларов.
# 4534.7-4537.6: - У тебя слева классный удар.
# - Ты тоже неплохо дерешься.
# 4537.8-4539.3: Спасибо.
# 4542.2-4544.5: Помнишь наш отпуск в Астоне?
# 4545.6-4547.4: Почему ты уехал?
# 4548.7-4551.0: - Жан Люк Гаспар.
# - О, господи!
# 4552.4-4553.8: Моя мечта.
# 4554.0-4556.6: - Забудь.
# - Надо же.
# 4557.2-4558.3: Неужели ты не слышала,
# 4558.5-4561.1: как меня на годовщину
# свадьбы высаживали с вертолета?
# 4561.6-4563.5: - Нет.
# - Нет?
# 4565.5-4567.1: Разрывные гранаты.
# 4567.3-4569.4: Я вообще тогда ничего не слышала.
# 4590.0-4592.8: Три ребра, куча растяжений,
# 4593.1-4595.1: уши переломаны.
# 4599.1-4601.6: А у тебя не бывает проблем со сном?
# 4603.5-4604.8: Не бывает.
# 4605.0-4606.7: У меня тоже.
# 4618.7-4621.3: Начать атаку! Они внутри!
# 4622.9-4625.7: Ты туда, я за тобой.
# 4637.2-4639.4: Беги, беги, беги!
# 4643.6-4644.9: Тихо.
# 4650.0-4652.1: Мне дали 48 часов, чтобы тебя убрать.
# 4652.4-4653.8: А мне на тебя тоже.
# 4654.0-4656.0: И мы еще говорим о доверии.
# 4656.2-4657.8: А чего ты ждал?
# 4663.6-4665.6: Я не люблю женское оружие.
#
# === Сцена 34 (100.6 сек, 7 реплик) ===
# 4668.7-4670.9: - Ты издеваешься?
# - Нет.
# 4671.5-4673.2: Спасибо.
# 4676.9-4678.8: Запускай!
# 4699.7-4701.0: ТОПЛИВО
# 4710.6-4712.4: Выходим, выходим!
# 4760.8-4763.0: Нужна машина.
# 4767.6-4769.3: Коулманы.
#
# === Сцена 35 (46.6 сек, 9 реплик) ===
# 4771.8-4774.4: Он мне семь месяцев мангал не отдает.
# 4775.6-4777.4: Я не служила в Корпусе Мира.
# 4777.5-4780.9: Что? Нет!
# Я за это тебя так уважал!
# 4781.1-4783.3: Зря мы решили говорить
# друг другу правду.
# 4783.5-4786.5: Нет, нет, нет.
# А я не учился у МТИ.
# 4786.7-4789.0: - А где?
# - Университет Ноттердама.
# 4789.2-4791.3: История искусств.
# 4793.1-4795.1: Для расширения кругозора.
# 4816.1-4818.5: А контора омолаживается.
#
# === Сцена 36 (239.2 сек, 45 реплик) ===
# 4823.9-4827.7: Мне никогда не нравилось
# то, как ты готовишь.
# 4828.8-4830.9: Это совершенно не твое.
# 4831.0-4833.6: Я у плиты ни разу в жизни не стояла.
# 4835.0-4837.4: Еда из ресторана.
# 4839.2-4841.5: Сплошная ложь!
# 4854.1-4855.9: Как мне это нравится.
# 4860.0-4862.1: - За нами хвост.
# - Что?
# 4863.8-4865.8: Черт, я сейчас.
# 4875.2-4876.7: Милый, держи прямо, не виляй.
# 4876.8-4878.8: Это называется
# "уход от погони", любимая.
# 4882.5-4884.5: Держи прямо.
# 4890.9-4894.1: Машину качает во все стороны.
# Как этот придурок ею управляет?
# 4896.9-4899.4: Трансмиссия кошмарная.
# 4901.7-4903.8: - Дай я сяду за руль.
# - Я сам.
# 4904.0-4905.6: Пусти меня.
# 4905.8-4907.2: Пусти.
# 4907.4-4909.3: Я всегда ездила на таких машинах.
# 4909.5-4911.7: - Я же домохозяйка.
# - Ладно. Давай.
# 4913.8-4914.8: - Давай.
# - Даю.
# 4915.0-4916.4: - Давай!
# - Сейчас.
# 4925.4-4927.2: Бронированные.
# 4927.6-4929.4: Бронированные.
# 4938.6-4943.1: Должен тебе признаться,
# я уже был женат.
# 4949.0-4950.8: Господи Иисусе!
# 4951.0-4952.4: Ты что, с ума сошла? Что с тобой?
# 4952.6-4953.7: Это ты меня довел.
# 4953.9-4955.4: - Это было в Вегасе по пьяни.
# - Еще лучше.
# 4955.6-4956.9: - Прекрати!
# - Намного лучше.
# 4957.1-4958.1: Молодец, Джон.
# 4958.3-4959.8: Хватит.
# 4966.3-4967.8: Гони, гони, гони!
# 4975.8-4977.7: Ее имя и номер страховки?
# 4977.9-4979.6: Чтоб ты ее убила?
# 5006.4-5008.5: Удобная конструкция дверей.
# 5015.1-5018.5: Знаешь, солнышко,
# тебе бы только критиковать.
# 5018.7-5020.8: Можно подумать,
# ты говоришь правду.
# 5024.2-5026.6: Джон, мои родители
# 5027.4-5029.4: погибли, когда мне было пять лет.
# 5029.6-5032.8: Вот как? А что за дядька
# тогда тебя замуж выдавал?
# 5033.2-5035.1: Нанятый актер.
# 5037.0-5039.8: А я говорил, что видел твоего
# папу в телешоу "Остров фантазий".
# 5040.0-5041.5: Я знаю.
# 5041.7-5043.5: Я больше не хочу это обсуждать.
# 5058.9-5060.7: - На мушке?
# - На мушке.
# 5061.4-5063.1: - Внимание.
# - Давай!
#
# === Сцена 37 (47.9 сек, 18 реплик) ===
# 5104.0-5106.7: Нам теперь придется
# заново узнавать друг друга.
# 5108.8-5110.3: Я еврейка.
# 5112.5-5115.4: А я-то дурак,
# привел на свадьбу настоящих родителей.
# 5115.7-5117.1: Какая гадость.
# 5117.3-5119.5: Как можно такое подавать?
# Простите, можно разогреть?
# 5119.7-5122.8: Мисс, я с вами разговариваю.
# Вы слышите?
# 5124.8-5126.7: Надо же, Джонни.
# 5126.9-5128.8: - Доброе утро, Эдди.
# - Доброе.
# 5129.4-5131.4: Рад, что ты живой, брат.
# 5132.9-5135.9: Ты одумался
# и прикончил эту лживую тварь?
# 5136.2-5138.3: Ты про меня?
# 5138.7-5141.2: - Кажется, я погорячился.
# - Точно.
# 5141.4-5142.6: - Прости.
# - Слушай.
# 5142.7-5143.9: Рад тебя видеть, Джейн.
# 5144.2-5146.5: Эдди, слушай внимательно.
# У нас проблемы.
# 5146.8-5148.7: Проблемы у тех,
# кто сидит на крэке, друг мой.
# 5148.9-5150.6: - Ясно.
# - А вы засветились.
# 5150.8-5152.0: - Возможно.
# - Возможно?
#
# === Сцена 38 (14.4 сек, 6 реплик) ===
# 5152.2-5154.1: Да вся наша контора на тебя охотится.
# 5154.3-5156.1: Вполне возможно,
# что ее контора тоже.
# 5156.3-5157.5: - Ну а ты?
# - Я?
# 5157.7-5159.7: - Ты-то что?
# - А что я?
# 5160.7-5163.4: Я сегодня от усталости еле ноги волочу.
# 5164.3-5166.6: И вообще, ты мне денег должен.
#
# === Сцена 39 (12.6 сек, 5 реплик) ===
# 5170.5-5172.1: - Так ты считаешь...
# - Нам друг друга не понять.
# 5172.3-5174.2: Это сразу видно,
# и не нужно на меня так смотреть.
# 5174.4-5177.8: Я уже очень давно знаю Джона
# и занимаю заметное место в его жизни.
# 5178.0-5180.8: Они взорвали мой дом,
# стреляли в мою жену.
# 5181.0-5183.0: Моя собственная контора.
#
# === Сцена 40 (27.5 сек, 12 реплик) ===
# 5183.4-5187.3: Если она работает на тех,
# на кого я думаю,
# 5188.4-5190.4: то вы как два супермаркета.
# 5190.6-5192.0: Скажем она с метеоканала,
# 5192.2-5195.7: а ты работаешь на том канале,
# который конкурирует с метеоканалом.
# 5195.8-5197.4: Вы успеваете за ходом моих мыслей?
# 5197.6-5199.0: Джонни, все очень просто.
# 5199.1-5201.7: Как только вы
# переходите границу - все!
# 5201.9-5202.8: Вы находитесь за границей.
# 5203.0-5204.2: Насколько это серьезно?
# 5204.4-5206.2: Насколько серьезно?
# 5206.6-5208.7: Помнишь Канаду?
# 5209.4-5210.9: То были детские шалости.
#
# === Сцена 41 (40.8 сек, 13 реплик) ===
# 5211.2-5212.5: - Ты и там был?
# - Завидуешь?
# 5212.6-5213.9: Она тебя чуть не задавила.
# 5214.1-5216.4: Это не мое дело.
# Настоящий друг в такие вещи не лезет.
# 5216.6-5220.4: Факты таковы: если вы разбежитесь,
# то у тебя появятся шанс.
# 5220.6-5223.0: Небольшой, Джонни, но шанс.
# 5223.2-5226.8: Останетесь вместе - конец.
# 5227.0-5230.5: Если вы не сможете найти то,
# что им нужно больше, чем вы.
# 5235.5-5239.4: Нашла. Его держат в подземном
# блоке "Д", в здании федерального суда.
# 5239.6-5242.4: Охраняют очень мощно.
# Всякие термодатчики движения,
# 5242.6-5244.3: инфракрасные сенсоры.
# 5245.4-5248.4: Даже нам туда не пробраться, Джейн.
# 5248.6-5249.9: Я знаю.
# 5250.1-5252.0: - Спасибо, Джесси.
# - Удачи тебе.
#
# === Сцена 42 (46.9 сек, 7 реплик) ===
# 5260.5-5263.6: Ребята, может, вы
# переключите канал?
# 5265.0-5269.9: Ник, будь добр, оторви от стула
# свою задницу и переключи канал.
# 5270.4-5273.6: Я знаю, это трудно. Спасибо.
# 5292.6-5296.0: - Ждем вас через 45 минут.
# - Да, знаем, они на подходе.
# 5301.3-5304.0: У нас будет 30 секунд, я вырубаю
# электричество, ты забираешь парня.
# 5304.2-5305.5: Просто, но эффективно. Ты понял?
# 5305.7-5307.4: Да, любимая.
#
# === Сцена 43 (21.7 сек, 6 реплик) ===
# 5307.7-5311.0: Ну, расскажи мне, у тебя много?
# 5312.2-5313.8: Какая разница?
# 5314.4-5316.9: - Хочешь, я первый скажу?
# - Давай.
# 5317.4-5322.4: Я не веду
# точный подсчет, но, наверное,
# 5323.0-5325.3: где-то в районе 60.
# 5327.3-5329.4: Это приблизительно, но...
#
# === Сцена 44 (197.2 сек, 50 реплик) ===
# 5329.6-5332.2: - гораздо важнее, что...
# - 312.
# 5333.8-5336.4: 312 человек?
# 5337.9-5341.0: - Но как?
# - Иногда это были пары.
# 5346.4-5350.3: - Милый?
# - Нет, нет...
# 5355.5-5358.1: - Следи за периметром.
# - Я все проверила.
# 5358.6-5361.8: - Что на полицейской частоте?
# - Я все контролирую.
# 5361.9-5364.4: - Не сердись.
# - Это не первая моя операция.
# 5365.0-5367.4: Ну, мы же закрыли тему.
# 5374.1-5376.0: Здесь налево.
# 5376.2-5378.2: Налево, Джон.
# 5378.6-5380.5: Налево.
# 5380.8-5383.4: Слушай, не нужно со мной так, хорошо?
# 5383.6-5384.9: Понежнее.
# 5385.1-5387.4: - Налево, пожалуйста.
# - Я не могу налево.
# 5387.6-5390.0: Видишь? Вот что у нас слева, смотри.
# 5391.0-5393.3: Или прямо, или назад.
# 5393.5-5394.5: А налево никак.
# 5394.7-5397.0: - Так куда мне ползти?
# - Оставайся на месте, я сейчас.
# 5397.2-5398.9: Видишь, куда я залез?
# 5399.1-5401.1: Видишь?
# 5401.8-5403.6: - Ну что там?
# - Да, сейчас, подожди.
# 5403.7-5406.3: Оставайся там, жди указаний,
# я найду выход.
# 5408.5-5410.8: Жди моих указаний.
# 5414.6-5418.6: Вот, почти. Не понимаю
# что там, потерпи.
# 5425.9-5428.8: Джон, что ты делаешь?
# Что ты делаешь?
# 5430.1-5432.6: По моему сигналу отключай свет.
# 5433.6-5436.4: Давай, вырубай свет.
# 5437.5-5439.3: Джейн, вырубай свет.
# 5441.2-5445.0: Нет, нет, нет,
# верни все обратно. Верни.
# 5445.6-5448.5: Ник, сними с меня наручники.
# 5448.7-5451.1: Джейн, включи свет.
# Мне нужно осмотреться.
# 5451.3-5453.0: О, боже.
# 5453.7-5455.7: - Свет, свет, врубай свет!
# - Сейчас.
# 5455.9-5458.8: - Черт, мне нужен свет!
# - Заткнись.
# 5461.9-5464.4: - Ник!
# - Да заткнись ты!
# 5469.7-5471.8: Ник, дай мне пистолет.
# 5490.2-5492.3: Тяжелый, гад.
# 5493.6-5496.0: Ну, все, готово.
# 5502.3-5504.4: Я же просила дождаться моего сигнала.
# 5504.6-5506.8: - Я сымпровизировал.
# - Ты отклонился от плана.
# 5507.0-5509.3: - План был гнилой.
# - Вовсе нет.
# 5509.5-5511.1: Дурацкий.
# 5511.3-5512.6: Продуманный.
# 5512.8-5514.4: В нашей работе
# успех зависит от интуиции.
# 5514.6-5515.7: Ты активизировал
# все охранные системы.
# 5515.9-5518.7: Моя интуиция нам помогла,
# и мы выполнили задание.
# 5518.9-5520.4: Черти что, как всегда.
# 5520.6-5522.4: Так было и на первую годовщину,
# 5522.6-5525.0: и когда ты забыл
# поздравить маму с днем рождения.
# 5525.2-5526.9: Твою выдуманную маму.
#
# === Сцена 45 (68.6 сек, 22 реплик) ===
# 5527.1-5529.7: Ты просто не в состоянии
# работать в команде.
# 5529.9-5532.6: Тебе не команда нужна,
# а послушный слуга.
# 5532.8-5535.1: Мне нужен надежный человек.
# 5535.5-5538.0: Джейн,
# с тобой без спросу вздохнуть нельзя.
# 5538.6-5540.4: Интересно, что ты имеешь в виду?
# 5540.5-5542.1: Пойми, ты не оставляешь человеку
# право на ошибку.
# 5542.3-5544.6: Ты нетерпима, никакой спонтанности.
# 5544.8-5547.0: - Кто на это согласится?
# - И не соглашайся.
# 5547.1-5549.4: У нас ведь не настоящая свадьба была.
# 5551.7-5554.1: - Кто вы такие?
# - Заткнись!
# 5559.6-5562.1: Итак, ты стал невольным
# свидетелем того,
# 5562.3-5564.7: как мы с женой
# обсуждали семейные проблемы.
# 5565.7-5567.6: Это печально.
# 5569.2-5572.6: Но с твоей стороны будет
# ошибкой не воспринять нас всерьез.
# 5573.0-5575.5: А теперь рассказывай все, что знаешь.
# 5575.7-5578.4: Почему боссы наших контор
# желают тебе смерти?
# 5579.8-5581.8: Ты знаешь.
# 5582.0-5584.8: Милая, пожалуйста.
# 5585.8-5587.4: Заканчивай.
# 5587.6-5590.9: Мне кажется, не стоит
# подрывать авторитет в глазах заложника.
# 5591.1-5593.6: Он может неверно истолковать ситуацию.
# 5593.8-5595.7: Прости.
#
# === Сцена 46 (11.5 сек, 5 реплик) ===
# 5598.7-5601.7: Итак, на чем я остановился?
# 5601.8-5603.7: - На счет воспринять всерьез.
# - Молчи и слушай.
# 5603.8-5606.1: Я изложу тебе все варианты, хорошо?
# 5606.4-5607.8: - Вариант номер один.
# - А можно?..
# 5608.0-5610.1: Заткнись. Вариант номер один.
#
# === Сцена 47 (165.0 сек, 38 реплик) ===
# 5610.4-5612.8: Ты говоришь, мы слушаем.
# Тебе не больно.
# 5613.0-5618.0: Вариант номер два: ты молчишь,
# я удаляю клещами твои большие пальцы,
# 5618.1-5619.6: будет больно.
# 5619.8-5624.3: И третий вариант: некоторые детали
# поменяются, но финал все тот же,
# 5624.4-5626.4: ты умрешь.
# 5628.9-5632.0: Бенджамин,
# не испытывай наше терпение.
# 5638.6-5640.7: Джейн, ты не могла бы сделать
# фруктовый коктейльчик?
# 5640.9-5642.2: Ну, я не знаю, клубничный, что ли.
# 5643.6-5646.9: Вариант номер один!
# 5647.2-5649.4: Что ж, отличный удар.
# 5654.2-5655.9: Что, у тебя спазм?
# 5656.1-5657.5: У меня привязаны руки.
# 5657.7-5659.6: Возьмите у меня в кармане.
# 5667.6-5670.0: Их цель - вы, а не я.
# 5670.2-5672.0: Вы оба.
# 5672.2-5673.3: В конторах узнали, что вы женаты,
# 5673.5-5675.8: и решили послать вас
# на одно и то же задание.
# 5676.2-5679.0: Это совместная операция
# двух ваших контор.
# 5679.2-5682.0: Они хотели, чтобы вы сами
# друг друга устранили.
# 5684.7-5686.8: А ты наживка.
# 5687.2-5690.0: Для меня это шанс
# остаться в конторе.
# 5690.2-5692.4: Пара трупов - и меня бы взяли.
# 5692.5-5694.0: Это прикольно.
# 5694.2-5695.7: Зачем ты хранил фотку в брюках?
# 5695.9-5697.0: Надо было в рамку поставить?
# 5697.2-5698.8: Избавиться от нее, сжечь.
# 5699.0-5700.1: Спецкурс 1-0-1.
# 5700.4-5701.9: Ну, извини, ту лекцию я прогулял.
# 5702.1-5704.5: Зато я знаю,
# что нельзя жениться на врагах.
# 5704.8-5707.4: Он до сих пор
# остается наживкой.
# 5711.4-5714.0: Пояс. Пояс, чувак.
# 5721.6-5723.5: Две минуты.
# 5724.6-5726.3: Одна минута.
# 5728.6-5730.5: Вперед, вперед!
# 5747.7-5749.5: - Чисто?
# - Чисто.
# 5750.7-5752.6: Развяжите меня.
# 5754.9-5758.3: У меня откололся кусок зуба.
# Мне это компенсируют?
# 5772.9-5775.4: Я проберусь в Лопаз,
# у меня там катер.
#
# === Сцена 48 (23.5 сек, 6 реплик) ===
# 5778.6-5782.1: А я спрячусь в Атласке, в горах.
# А что дальше?
# 5782.3-5784.8: По одиночке у нас больше шансов.
# 5787.2-5789.7: Я не хочу знать, что дальше.
# 5790.4-5792.5: Ты что скажешь?
# 5796.6-5799.9: Семейная жизнь нам не удалась,
# согласен.
# 5800.1-5802.1: Вляпались в дурацкую ситуацию.
#
# === Сцена 49 (150.5 сек, 9 реплик) ===
# 5802.4-5804.6: Бог знает во что.
# 5805.9-5808.3: Я не хочу бегать всю жизнь.
# 5810.9-5813.8: Я предлагаю остаться и драться.
# 5814.0-5816.2: Освободиться от них.
# 5816.4-5818.7: Если хочешь уйти, иди.
# 5818.9-5821.0: Спасибо.
# 5822.2-5826.0: Ну а сейчас
# давай попробуем освободиться.
# 5878.7-5880.7: Классный магазин.
# 5949.9-5952.9: - До встречи, Джейн.
# - Увидимся, Джон.
#
# === Сцена 50 (227.1 сек, 13 реплик) ===
# 6049.4-6052.7: - Мазила.
# - Прости.
# 6056.5-6058.6: Потом поговорим.
# 6072.8-6074.7: Ты чего?
# 6076.8-6079.6: - Я ничего не трогал.
# - Ну конечно!
# 6118.4-6120.8: - Прости, что я попала ножом.
# - Не будем об этом.
# 6126.7-6128.9: - Я сверху.
# - А я их выманю.
# 6129.9-6131.6: Иду по часовой. Прикрой.
# 6131.8-6133.3: Ясно.
# 6253.1-6255.7: Что скажешь?
# 6258.0-6260.1: Прорвемся.
# 6268.8-6271.1: С этими осторожнее.
# 6271.4-6273.3: Их иногда клинит.
# 6274.1-6276.5: Ты берешь тех, кто слева,
# а я - тех, кто справа.
#
# === Сцена 51 (26.0 сек, 5 реплик) ===
# 6290.4-6293.6: Хорошо бы сейчас оказаться
# в Лопазе на твоем катере.
# 6297.9-6300.4: Там сейчас дождь поливает.
# 6307.0-6309.0: А мне никуда не хочется.
# 6309.2-6311.8: Здесь хорошо. С тобой.
# 6314.7-6316.4: Молчи.
#
# === Сцена 52 (27.4 сек, 10 реплик) ===
# 6402.3-6404.9: Интересно,
# каких же успехов вам удалось добиться?
# 6405.1-6412.0: Вроде все неплохо, правда, бывают
# моменты, когда мне хочется ее убить.
# 6412.2-6414.7: - Что мешает?
# - Рука не поднимается.
# 6414.7-6415.9: Это хороший знак.
# 6416.1-6418.4: Нужно наступать
# на горло собственной песне.
# 6418.6-6419.9: Такова семейная жизнь.
# 6420.1-6422.2: Да, надавить на самое яблочко.
# 6423.1-6424.9: О, мы ремонт сделали.
# 6425.1-6427.1: Действительно, капитальный.
# 6427.3-6429.7: Жизнь постоянно бросает нам вызовы.
#
# === Сцена 53 (28.0 сек, 10 реплик) ===
# 6429.9-6431.8: - Испытывает нас.
# - Это правда.
# 6432.4-6435.2: Но вы все преодолеете вместе.
# 6435.4-6437.9: - Кто знает?
# - Конечно, кто знает?
# 6439.6-6441.2: Как это так?
# 6441.4-6443.0: Всякое может случиться.
# 6443.3-6444.9: Кто знает?
# 6445.1-6447.8: Вы считаете, что стиль
# ваших отношений изменился?
# 6448.0-6451.3: - Это способствует...
# - Вас снова секс интересует?
# 6451.9-6454.4: Джон?
# 6455.5-6457.9: Что ж, хватит.
# /tmp/ipython-input-5-2615003874.py:123: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   similarity = prev_sub.doc.similarity(curr_sub.doc) if prev_sub.doc and curr_sub.doc else 0
# /tmp/ipython-input-5-2615003874.py:100: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   similarity = prev_scene[-1].doc.similarity(current_scene[0].doc)
# /tmp/ipython-input-5-2615003874.py:83: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   sim = scene[i-1].doc.similarity(scene[i].doc)
# Результат также сохранён в файл scenes_output.txt
